# %%
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

openai_client = OpenAI()

# %%
from rag_helper import RAGBase
from sqlitesearch import TextSearchIndex

# %%
sqlite_index = TextSearchIndex(
    text_fields = ['question','answer', 'section'],
    keyword_fields=['course'],
    db_path='faq.db'
)

# %%
assistant = RAGBase(sqlite_index, openai_client)

# %%
assistant.rag('How do I run Olama locally?')
# Out:
# 'First, install Ollama from https://ollama.com/download for your OS.\n\nThen run it locally with:\n\n```bash\nollama run llama3\n```\n\nThis will download the model and start a local chat interface.\n\nTo check that the local server is running, you can also test:\n\n```bash\ncurl http://localhost:11434\n```\n\nIf you meant “Ollama” and not “Olama,” this is the local run command from the context.'
